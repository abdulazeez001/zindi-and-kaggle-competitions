# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
test_data = pd.read_csv(r"C:\Users\UNION\Documents\intercampusai2019\train.csv")

# %%
test_data.head()
# Out:
#     EmployeeNo                               Division        Qualification  \
# 0  YAK/S/00001         Commercial Sales and Marketing     MSc, MBA and PhD
# 1  YAK/S/00002  Customer Support and Field Operations  First Degree or HND
# 2  YAK/S/00003         Commercial Sales and Marketing  First Degree or HND
# 3  YAK/S/00004         Commercial Sales and Marketing  First Degree or HND
# 4  YAK/S/00006               Information and Strategy  First Degree or HND
#
#    Gender   Channel_of_Recruitment  Trainings_Attended  Year_of_birth  \
# 0  Female  Direct Internal process                   2           1986
# 1    Male        Agency and others                   2           1991
# 2    Male  Direct Internal process                   2           1987
# 3    Male        Agency and others                   3           1982
# 4    Male  Direct Internal process                   3           1990
#
#    Last_performance_score  Year_of_recruitment  Targets_met  Previous_Award  \
# ...

# %%
test_data.columns
# Out:
# Index(['EmployeeNo', 'Division', 'Qualification', 'Gender',
#        'Channel_of_Recruitment', 'Trainings_Attended', 'Year_of_birth',
#        'Last_performance_score', 'Year_of_recruitment', 'Targets_met',
#        'Previous_Award', 'Training_score_average', 'State_Of_Origin',
#        'Foreign_schooled', 'Marital_Status', 'Past_Disciplinary_Action',
#        'Previous_IntraDepartmental_Movement', 'No_of_previous_employers',
#        'Promoted_or_Not'],
#       dtype='object')

# %%
test_data1 = test_data.drop("EmployeeNo" ,axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
test_data1.columns
# Out:
# Index(['Division', 'Qualification', 'Gender', 'Channel_of_Recruitment',
#        'Trainings_Attended', 'Year_of_birth', 'Last_performance_score',
#        'Year_of_recruitment', 'Targets_met', 'Previous_Award',
#        'Training_score_average', 'State_Of_Origin', 'Foreign_schooled',
#        'Marital_Status', 'Past_Disciplinary_Action',
#        'Previous_IntraDepartmental_Movement', 'No_of_previous_employers',
#        'Promoted_or_Not'],
#       dtype='object')

# %%
columns = ['Division', 'Qualification', 'Gender', 'Channel_of_Recruitment',
        'State_Of_Origin', 'Foreign_schooled',
       'Marital_Status', 'Past_Disciplinary_Action',
       'Previous_IntraDepartmental_Movement', 'No_of_previous_employers']

# %%
for col in columns:
    test_data1[col] = label.fit_transform(test_data1[col])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-31aeb11ee931> in <module>
#       1 for col in columns:
# ----> 2     test_data1[col] = label.fit_transform(test_data1[col])
#
# ~\myconda\lib\site-packages\sklearn\preprocessing\label.py in fit_transform(self, y)
#     234         """
#     235         y = column_or_1d(y, warn=True)
# --> 236         self.classes_, y = _encode(y, encode=True)
#     237         return y
#     238
#
# ~\myconda\lib\site-packages\sklearn\preprocessing\label.py in _encode(values, uniques, encode)
#     106     """
#     107     if values.dtype == object:
# --> 108         return _encode_python(values, uniques, encode)
#     109     else:
#     110         return _encode_numpy(values, uniques, encode)
#
# ~\myconda\lib\site-packages\sklearn\preprocessing\label.py in _encode_python(values, uniques, encode)
# ...

# %%
test_data1.head()
# Out:
#    Division        Qualification  Gender   Channel_of_Recruitment  \
# 0         1     MSc, MBA and PhD  Female  Direct Internal process
# 1         2  First Degree or HND    Male        Agency and others
# 2         1  First Degree or HND    Male  Direct Internal process
# 3         1  First Degree or HND    Male        Agency and others
# 4         4  First Degree or HND    Male  Direct Internal process
#
#    Trainings_Attended  Year_of_birth  Last_performance_score  \
# 0                   2           1986                    12.5
# 1                   2           1991                    12.5
# 2                   2           1987                     7.5
# 3                   3           1982                     2.5
# 4                   3           1990                     7.5
#
#    Year_of_recruitment  Targets_met  Previous_Award  Training_score_average  \
# 0                 2011            1               0                      41
# ...

# %%
columns = ['Division','Gender', 'Channel_of_Recruitment',
        'State_Of_Origin', 'Foreign_schooled',
       'Marital_Status', 'Past_Disciplinary_Action',
       'Previous_IntraDepartmental_Movement', 'No_of_previous_employers']

# %%
for col in columns:
    test_data1[col] = label.fit_transform(test_data1[col])

# %%
test_data1["Qualification"].isnull().sum()
# Out:
# 1679

# %%
test_data1["Qualification"].unique()
# Out:
# array(['MSc, MBA and PhD', 'First Degree or HND', nan,
#        'Non-University Education'], dtype=object)

# %%
test_data2 = test_data1.drop("Qualification",axis=1)

# %%
test_data2.head()
# Out:
#    Division  Gender  Channel_of_Recruitment  Trainings_Attended  \
# 0         1       0                       1                   2
# 1         2       1                       0                   2
# 2         1       1                       1                   2
# 3         1       1                       0                   3
# 4         4       1                       1                   3
#
#    Year_of_birth  Last_performance_score  Year_of_recruitment  Targets_met  \
# 0           1986                    12.5                 2011            1
# 1           1991                    12.5                 2015            0
# 2           1987                     7.5                 2012            0
# 3           1982                     2.5                 2009            0
# 4           1990                     7.5                 2012            0
#
#    Previous_Award  Training_score_average  State_Of_Origin  Foreign_schooled  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
import xgboost as xgb

# %%
test_data2.columns
# Out:
# Index(['Division', 'Gender', 'Channel_of_Recruitment', 'Trainings_Attended',
#        'Year_of_birth', 'Last_performance_score', 'Year_of_recruitment',
#        'Targets_met', 'Previous_Award', 'Training_score_average',
#        'State_Of_Origin', 'Foreign_schooled', 'Marital_Status',
#        'Past_Disciplinary_Action', 'Previous_IntraDepartmental_Movement',
#        'No_of_previous_employers', 'Promoted_or_Not'],
#       dtype='object')

# %%
ydata= test_data2['Promoted_or_Not']
xdata = test_data2.drop(['Promoted_or_Not'], axis = 1)

# %%
len(xdata['No_of_previous_employers'])
# Out:
# 38312

# %%
def nope():
    for i in range(len(xdata['No_of_previous_employers'])):
        if xdata.loc[i, 'No_of_previous_employers']=='1':
             xdata.loc[i, 'No_of_previous_employers']=1
        if xdata.loc[i, 'No_of_previous_employers']=='2':
             xdata.loc[i, 'No_of_previous_employers']=2
        if xdata.loc[i, 'No_of_previous_employers']=='3':
             xdata.loc[i, 'No_of_previous_employers']=3
        if xdata.loc[i, 'No_of_previous_employers']=='4':
             xdata.loc[i, 'No_of_previous_employers']=4
        if xdata.loc[i, 'No_of_previous_employers']=='5':
             xdata.loc[i, 'No_of_previous_employers']=5
        if xdata.loc[i, 'No_of_previous_employers']=='6':
             xdata.loc[i, 'No_of_previous_employers']=6
                
    return xdata

# %%
xdata1=nope()

# %%
xdata['No_of_previous_employers'].unique()
# Out:
# array([0, 1, 4, 3, 2, 6, 5], dtype=int64)

# %%
def nope1():
    for i in range(len(xdata['No_of_previous_employers'])):
        if xdata1.loc[i, 'No_of_previous_employers']=='0':
             xdata1.loc[i, 'No_of_previous_employers']=0
        if xdata1.loc[i, 'No_of_previous_employers']=='More than 5':
             xdata1.loc[i, 'No_of_previous_employers']=6            
    return xdata1

# %%
xdata2=nope1()

# %%
xdata2['No_of_previous_employers'].unique()
# Out:
# array([0, 1, 4, 3, 2, 6, 5], dtype=int64)

# %%
data_dmatrix = xgb.DMatrix(data=xdata,label=ydata)

# %%
xg = xgb.XGBClassifier(objective ='reg:logistic', colsample_bytree = 0.5, learning_rate = 0.1,
                max_depth = 7, alpha = 10, n_estimators = 700, )

# %%
xg.fit(xdata,ydata)
# Out:
# XGBClassifier(alpha=10, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=0.5, gamma=0,
#        learning_rate=0.01, max_delta_step=0, max_depth=7,
#        min_child_weight=1, missing=None, n_estimators=700, n_jobs=1,
#        nthread=None, objective='reg:logistic', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#        subsample=1, verbosity=1)

# %%
tdata = pd.read_csv(r"C:\Users\UNION\Documents\intercampusai2019\test.csv")

# %%
tdata1 = tdata.drop("EmployeeNo" ,axis=1)

# %%
tdata1.columns
# Out:
# Index(['Division', 'Qualification', 'Gender', 'Channel_of_Recruitment',
#        'Trainings_Attended', 'Year_of_birth', 'Last_performance_score',
#        'Year_of_recruitment', 'Targets_met', 'Previous_Award',
#        'Training_score_average', 'State_Of_Origin', 'Foreign_schooled',
#        'Marital_Status', 'Past_Disciplinary_Action',
#        'Previous_IntraDepartmental_Movement', 'No_of_previous_employers'],
#       dtype='object')

# %%
for col in columns:
    tdata1[col] = label.fit_transform(tdata1[col])

# %%
tdata2 = tdata1.drop("Qualification",axis=1)

# %%
tdata2.head()
# Out:
#    Division  Gender  Channel_of_Recruitment  Trainings_Attended  \
# 0         3       1                       0                   2
# 1         3       1                       1                   2
# 2         7       1                       1                   2
# 3         2       1                       0                   2
# 4         3       1                       0                   2
#
#    Year_of_birth  Last_performance_score  Year_of_recruitment  Targets_met  \
# 0           1976                     7.5                 2017            0
# 1           1991                     0.0                 2018            0
# 2           1984                     7.5                 2012            0
# 3           1984                     2.5                 2009            0
# 4           1983                     7.5                 2014            1
#
#    Previous_Award  Training_score_average  State_Of_Origin  Foreign_schooled  \
# ...

# %%
prexbg = xg.predict(tdata2)

# %%
m = GradientBoostingClassifier(n_estimators = 5000, learning_rate = 0.001, loss='exponential', subsample =0.5, max_depth = 10, min_samples_leaf=6, max_features=7, warm_start=True)
ada = AdaBoostClassifier(DecisionTreeClassifier(max_leaf_nodes = 100, random_state = 100, criterion = 'entropy', max_depth = 7,class_weight={1:5}),learning_rate=0.01, n_estimators=100 )

# %%
ada.fit(xdata,ydata)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight={1: 5}, criterion='entropy', max_depth=7,
#             max_features=None, max_leaf_nodes=100,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=100,
#             splitter='best'),
#           learning_rate=0.01, n_estimators=100, random_state=None)

# %%
preada = ada.predict(tdata2)

# %%
prexbg
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
tdata.head()
# Out:
#     EmployeeNo                                     Division  \
# 0  YAK/S/00005  Information Technology and Solution Support
# 1  YAK/S/00011  Information Technology and Solution Support
# 2  YAK/S/00015                      Research and Innovation
# 3  YAK/S/00016        Customer Support and Field Operations
# 4  YAK/S/00017  Information Technology and Solution Support
#
#          Qualification Gender   Channel_of_Recruitment  Trainings_Attended  \
# 0  First Degree or HND   Male        Agency and others                   2
# 1                  NaN   Male  Direct Internal process                   2
# 2     MSc, MBA and PhD   Male  Direct Internal process                   2
# 3  First Degree or HND   Male        Agency and others                   2
# 4  First Degree or HND   Male        Agency and others                   2
#
#    Year_of_birth  Last_performance_score  Year_of_recruitment  Targets_met  \
# ...

# %%
submission = {}
submission['EmployeeNo'] = tdata['EmployeeNo']
submission['Promoted_or_Not'] = prexbg
submissionDSN= pd.DataFrame(submission)
submissionDSN.to_csv('submissionDSN10.csv', index = False)

# %%
sdata = pd.read_csv(r"C:\Users\UNION\submissionDSN10.csv")

# %%
sdata
# Out:
#         EmployeeNo  Promoted_or_Not
# 0      YAK/S/00005                0
# 1      YAK/S/00011                0
# 2      YAK/S/00015                0
# 3      YAK/S/00016                0
# 4      YAK/S/00017                0
# 5      YAK/S/00019                0
# 6      YAK/S/00027                0
# 7      YAK/S/00028                0
# 8      YAK/S/00031                0
# 9      YAK/S/00032                0
# 10     YAK/S/00034                0
# 11     YAK/S/00038                0
# 12     YAK/S/00040                0
# 13     YAK/S/00041                0
# 14     YAK/S/00043                0
# 15     YAK/S/00045                0
# 16     YAK/S/00047                0
# 17     YAK/S/00049                0
# 18     YAK/S/00050                0
# 19     YAK/S/00051                0
# 20     YAK/S/00058                0
# 21     YAK/S/00060                0
# 22     YAK/S/00063                0
# 23     YAK/S/00067                0
# 24     YAK/S/00069                0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-211-0b052d41b57a> in <module>
# ----> 1 from imblearn.over_sampling import SMOTE
#
# ModuleNotFoundError: No module named 'imblearn'
